# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns


round0_df = pd.read_csv("../data/BoilerPlateCode.csv", delimiter= ";")
round0_df.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 1   -1          0              KELP         2028             1       2026.0
# 2   -1        100              KELP         2025            24          NaN
# 3   -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4   -1        200  RAINFOREST_RESIN         9995            20          NaN
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           2.0       9995.0          29.0        10004             2
# 1           2.0       2025.0          29.0         2029            31
# 2           NaN          NaN           NaN         2028             2
# 3          22.0          NaN           NaN        10004             2
# 4           NaN          NaN           NaN        10005            20
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
kelp_df = round0_df[round0_df["product"] == "KELP"]
kelp_df.head()
# Out:
#    day  timestamp product  bid_price_1  bid_volume_1  bid_price_2  \
# 1   -1          0    KELP         2028             1       2026.0
# 2   -1        100    KELP         2025            24          NaN
# 5   -1        200    KELP         2025            22          NaN
# 6   -1        300    KELP         2025            31          NaN
# 9   -1        400    KELP         2025            27          NaN
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 1           2.0       2025.0          29.0         2029            31
# 2           NaN          NaN           NaN         2028             2
# 5           NaN          NaN           NaN         2028            20
# 6           NaN          NaN           NaN         2028             2
# 9           NaN          NaN           NaN         2028            27
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 1          NaN           NaN          NaN           NaN     2028.5
# ...

# %%
sns.lineplot(data = kelp_df, x = "timestamp", y = "bid_price_1", label = "bid price 1")
sns.lineplot(data = kelp_df, x = "timestamp", y = "bid_price_2", label = "bid price 2")
sns.lineplot(data = kelp_df, x = "timestamp", y = "bid_price_3", label = "bid price 3")
plt.xlabel("Time Stamp")
plt.ylabel("Sea Shells")
# Out:
# Text(0, 0.5, 'Sea Shells')

# %%
sns.lineplot(data = kelp_df, x = "timestamp", y = "ask_price_1", label = "ask price 1")
sns.lineplot(data = kelp_df, x = "timestamp", y = "ask_price_2", label = "ask price 2")
sns.lineplot(data = kelp_df, x = "timestamp", y = "ask_price_3", label = "ask price 3")
plt.xlabel("Time Stamp")
plt.ylabel("Sea Shells")
# Out:
# Text(0, 0.5, 'Sea Shells')

# %%
def find_bid_avg(bid_idx, past_vals = 10):
    pass

def find_ask_avg(ask_idx, past_vals = 10):
    pass

def strategy_autoregressive(df):
    window_size = 10

    pass
