# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
round0_df = pd.read_csv("/Users/advaykadam/IMC_Prosperity/data/BoilerPlateCode.csv", delimiter= ";")
round0_df.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 1   -1          0              KELP         2028             1       2026.0
# 2   -1        100              KELP         2025            24          NaN
# 3   -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4   -1        200  RAINFOREST_RESIN         9995            20          NaN
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           2.0       9995.0          29.0        10004             2
# 1           2.0       2025.0          29.0         2029            31
# 2           NaN          NaN           NaN         2028             2
# 3          22.0          NaN           NaN        10004             2
# 4           NaN          NaN           NaN        10005            20
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# ...

# %%
round0_df.tail()
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 3995   -1     199700              KELP         2020            27
# 3996   -1     199800  RAINFOREST_RESIN         9995            21
# 3997   -1     199800              KELP         2020            21
# 3998   -1     199900              KELP         2020            32
# 3999   -1     199900  RAINFOREST_RESIN         9996             2
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 3995          NaN           NaN          NaN           NaN         2023
# 3996          NaN           NaN          NaN           NaN        10002
# 3997          NaN           NaN          NaN           NaN         2023
# 3998          NaN           NaN          NaN           NaN         2022
# 3999       9995.0          30.0          NaN           NaN        10004
#
#       ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# ...

# %%
sns.lineplot(data = round0_df[round0_df["product"] == "KELP"], x = "timestamp", y = "profit_and_loss")
# Out:
# <Axes: xlabel='timestamp', ylabel='profit_and_loss'>

# %%
sns.lineplot(data = round0_df[round0_df["product"] == "RAINFOREST_RESIN"], x = "timestamp", y = "profit_and_loss")
# Out:
# <Axes: xlabel='timestamp', ylabel='profit_and_loss'>

# %%
round0_df[round0_df["product"] == "RAINFOREST_RESIN"]["profit_and_loss"].sum()
# Out:
# -358462.0

# %%
sns.lineplot(data = round0_df, x = "timestamp", y = "profit_and_loss")
# Out:
# <Axes: xlabel='timestamp', ylabel='profit_and_loss'>

# %%
round0_df[round0_df["product"] == "KELP"]["bid_price_1"].describe()
# Out:
# count    2000.000000
# mean     2017.678500
# std         3.642633
# min      2009.000000
# 25%      2015.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2028.000000
# Name: bid_price_1, dtype: float64

# %%
round0_df[round0_df["product"] == "KELP"]["bid_price_2"].describe()
# Out:
# count     382.000000
# mean     2017.455497
# std         3.637348
# min      2010.000000
# 25%      2014.000000
# 50%      2018.000000
# 75%      2020.000000
# max      2026.000000
# Name: bid_price_2, dtype: float64

# %%
round0_df[round0_df["product"] == "KELP"]["bid_price_3"].describe()
# Out:
# count      33.000000
# mean     2016.727273
# std         3.859021
# min      2010.000000
# 25%      2013.000000
# 50%      2017.000000
# 75%      2019.000000
# max      2025.000000
# Name: bid_price_3, dtype: float64
